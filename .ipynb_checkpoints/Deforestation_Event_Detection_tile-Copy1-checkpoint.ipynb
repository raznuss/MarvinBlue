# %%
# Imports
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.dates as mdates
import geopandas as gpd
import rasterio
from rasterio.mask import mask
from shapely.geometry import Polygon
from sklearn.preprocessing import StandardScaler
import joblib
from datetime import datetime
import sys
from rasterio.plot import show

# Step 1: Load Time Series Data
time_series_dir = r"D:\Development\RESEARCH\MarvinBlue\Data\time_series"

# Get the list of all TIFF files in the directory sorted by date
tif_files = sorted([f for f in os.listdir(time_series_dir) if f.endswith('.tif')])

# Load a sample TIFF file to extract coordinate bounds
sample_tif_path = os.path.join(time_series_dir, tif_files[0])

# Step 2: Determine the Coordinate Range
with rasterio.open(sample_tif_path) as src:
    bounds = src.bounds
    crs = src.crs

# Print the coordinate range
print(f"Coordinate Reference System (CRS): {crs}")
print(f"Coordinate Range (Bounding Box):")
print(f"  Min Longitude (West): {bounds.left}")
print(f"  Max Longitude (East): {bounds.right}")
print(f"  Min Latitude (South): {bounds.bottom}")
print(f"  Max Latitude (North): {bounds.top}")

# Step 3: Define the Polygon
polygon_coords = [
    (846000.0, 9330500.0),  # Bottom-left corner
    (846000.0, 9331000.0),  # Top-left corner
    (846200.0, 9331000.0),  # Top-right corner
    (846200.0, 9330500.0)   # Bottom-right corner
]

# Create the Polygon object
polygon = Polygon(polygon_coords)

# Convert to GeoDataFrame (necessary for rasterio mask function)
gdf = gpd.GeoDataFrame([1], geometry=[polygon], crs=crs)

# Step 4: Plot the First TIFF File with the Polygon Overlaid
def plot_tif_with_polygon(tif_path, polygon_gdf):
    with rasterio.open(tif_path) as src:
        fig, ax = plt.subplots(figsize=(10, 10))
        
        # Plot the TIFF image (first band for visualization)
        show(src, ax=ax, title="First TIFF File with Polygon Overlay")

        # Plot the polygon on top
        polygon_gdf.plot(ax=ax, facecolor='none', edgecolor='red', linewidth=2)

        # Set the extent of the plot to the bounds of the image
        ax.set_xlim(src.bounds.left, src.bounds.right)
        ax.set_ylim(src.bounds.bottom, src.bounds.top)

        plt.show()

# Plot the first TIFF file with the polygon
plot_tif_with_polygon(os.path.join(time_series_dir, tif_files[0]), gdf)

# Step 5: Load the Model and Scaler
model_path = r'D:\Development\RESEARCH\MarvinBlue\Results\svm_model_tile.pkl'  # or 'svm_model_tile.pkl'
forest_classifier = joblib.load(model_path)

scaler_path = r'D:\Development\RESEARCH\MarvinBlue\Results\scaler_tile.pkl'
scaler = joblib.load(scaler_path)

# Step 6: Define the Feature Extraction Function
def extract_tile_features(band, i, j, window_size=1):
    """Extract features from a 3x3 tile around the pixel at (i, j) in the band, ensuring no NaNs in the tile."""
    tile = band[max(0, i-window_size):i+window_size+1, max(0, j-window_size):j+window_size+1]
    if np.isnan(tile).any():
        return None  # Skip tiles with NaN values
    mean_val = np.nanmean(tile)
    std_val = np.nanstd(tile)
    min_val = np.nanmin(tile)
    max_val = np.nanmax(tile)
    return mean_val, std_val, min_val, max_val

def extract_features(image_data):
    """Extract features from the first two bands (VV, VH)."""
    band1, band2 = image_data[0], image_data[1]
    h, w = band1.shape
    features = []

    for i in range(h):
        for j in range(w):
            band1_features = extract_tile_features(band1, i, j)
            band2_features = extract_tile_features(band2, i, j)
            if band1_features and band2_features:
                features.append(band1_features + band2_features)
    
    return np.array(features)

# Step 7: Define the Deforestation Detection Function
def is_deforested_rate_of_change(previous_percentage, current_percentage, rate_threshold=10):
    """Check if the rate of increase in non-forest percentage exceeds the threshold."""
    rate_of_change = current_percentage - previous_percentage
    return rate_of_change > rate_threshold

def smooth_data(data, window_size=5):
    """Apply a moving average to the data to smooth out short-term fluctuations."""
    return pd.Series(data).rolling(window=window_size).mean()

def is_deforested_moving_average(smoothed_percentage, threshold=50):
    """Check if the smoothed non-forest percentage exceeds the threshold."""
    return smoothed_percentage > threshold

def calculate_baseline(non_forest_summary, baseline_period):
    """Calculate the baseline non-forest percentage during a stable period."""
    baseline_values = [percentage for date, percentage in non_forest_summary if baseline_period[0] <= date <= baseline_period[1]]
    return np.mean(baseline_values)

def is_deforested_baseline(current_percentage, baseline, margin=20):
    """Check if the current percentage is significantly above the baseline."""
    return current_percentage > (baseline + margin)

def is_deforested_combination(previous_percentage, current_percentage, baseline, threshold=50, rate_threshold=10):
    """Combine rate of change and absolute threshold criteria to define deforestation."""
    rate_of_change = current_percentage - previous_percentage
    exceeds_threshold = current_percentage > (baseline + threshold)
    print(f"Rate of Change: {rate_of_change}, Exceeds Threshold: {exceeds_threshold}")
    return (rate_of_change > rate_threshold) and exceeds_threshold

def check_temporal_consistency(non_forest_summary, window_size=3, threshold=50):
    """Check if there's a consistent increase in non-forest percentage over multiple time steps."""
    smoothed_data = smooth_data([percentage for _, percentage in non_forest_summary], window_size)
    return all(x > threshold for x in smoothed_data[-window_size:])

def extract_date_from_filename(filename):
    """Extract the date from the filename, assuming the date is in a specific position."""
    date_str = filename.split('_')[4]  # Adjust based on your file name pattern
    return datetime.strptime(date_str, "%Y%m%dT%H%M%S").date()

def classify_and_detect_deforestation(polygon_gdf, tif_files, method='combination'):
    # Sort the files by date before processing
    tif_files = sorted(tif_files, key=extract_date_from_filename)
    
    previous_classification = None
    total_files = len(tif_files)
    non_forest_summary = []
    initial_predictions = None  # To store the initial prediction map
    initial_file_date = None
    final_predictions = None  # To store the final prediction map
    final_file_date = None
    deforestation_detected = False  # Track if deforestation has been detected
    deforestation_date = None  # To store the date of deforestation detection

    baseline_period = [datetime(2015, 1, 1).date(), datetime(2016, 1, 1).date()]  # Define your stable period here

    for index, tif_file in enumerate(tif_files):
        sys.stdout.write(f"\rProcessing file {index + 1} out of {total_files}...")
        sys.stdout.flush()

        tif_path = os.path.join(time_series_dir, tif_file)
        with rasterio.open(tif_path) as src:
            out_image, out_transform = mask(src, polygon_gdf.geometry, crop=True)
            out_image = out_image.astype(np.float32)
            out_image = np.nan_to_num(out_image, nan=-9999)

            h, w = out_image.shape[1], out_image.shape[2]
            valid_features = []

            for i in range(h):
                for j in range(w):
                    tile_features = extract_features(out_image[:, i:i+1, j:j+1])
                    if tile_features is not None:
                        valid_features.append(tile_features)

            if not valid_features:
                continue

            # Convert list of features into a 2D numpy array
            valid_features = np.vstack(valid_features)

            # Normalize the features using the scaler
            valid_features_normalized = scaler.transform(valid_features)

            # Classify the pixels using the loaded model
            predictions = forest_classifier.predict(valid_features_normalized).reshape(h, w)

            # Store the initial prediction map and date
            if initial_predictions is None:
                initial_predictions = predictions
                initial_file_date = extract_date_from_filename(tif_file)

            # Always update the final predictions and date
            final_predictions = predictions
            final_file_date = extract_date_from_filename(tif_file)

            # Calculate the number of non-forest pixels and the percentage
            non_forest_pixels = np.sum(predictions == 0)
            total_pixels = predictions.size
            non_forest_percentage = (non_forest_pixels / total_pixels) * 100

            # Store the summary data
            non_forest_summary.append((final_file_date, non_forest_percentage))

            # Choose the deforestation detection method
            if method == 'rate_of_change':
                if index > 0 and is_deforested_rate_of_change(non_forest_summary[index-1][1], non_forest_percentage):
                    deforestation_detected = True
                    deforestation_date = final_file_date
            elif method == 'moving_average':
                if len(non_forest_summary) >= 5:  # Ensure there are enough data points for smoothing
                    smoothed_percentages = smooth_data([percent for _, percent in non_forest_summary])
                    smoothed_percentage = smoothed_percentages.iloc[-1] if len(smoothed_percentages) > 0 else None
                    if smoothed_percentage is not None and is_deforested_moving_average(smoothed_percentage):
                        deforestation_detected = True
                        deforestation_date = final_file_date
            elif method == 'baseline':
                baseline = calculate_baseline(non_forest_summary, baseline_period)
                if is_deforested_baseline(non_forest_percentage, baseline):
                    deforestation_detected = True
                    deforestation_date = final_file_date
            elif method == 'combination':
                if index > 0:
                    baseline = calculate_baseline(non_forest_summary, baseline_period)
                    if is_deforested_combination(non_forest_summary[index-1][1], non_forest_percentage, baseline):
                        deforestation_detected = True
                        deforestation_date = final_file_date
            elif method == 'temporal_consistency':
                if check_temporal_consistency(non_forest_summary):
                    deforestation_detected = True
                    deforestation_date = final_file_date

            previous_classification = predictions

    # Plot the initial and final predictions only once
    if initial_predictions is not None and final_predictions is not None:
        visualize_predictions(initial_predictions, initial_file_date, final_predictions, final_file_date, out_transform)
        visualize_change_groups(initial_predictions, final_predictions, initial_file_date, final_file_date, out_transform)

    # Plot the summary and include the deforestation detection date
    plot_non_forest_percentage(non_forest_summary, tif_files, deforestation_date)

    if deforestation_detected:
        print(f"\nDeforestation detected on: {deforestation_date}")
    else:
        print("\nNo significant deforestation detected in the given time series.")

def plot_non_forest_percentage(non_forest_summary, tif_files, deforestation_date=None):
    """Plot the non-forest percentage over time with custom point colors based on file name prefix and mark deforestation detection date."""
    dates, percentages = zip(*non_forest_summary)

    # Create a color map for the points based on the file name prefix
    colors = []
    for tif_file in tif_files:
        if tif_file.startswith('S1A'):
            colors.append('green')
        elif tif_file.startswith('S1B'):
            colors.append('red')
        else:
            colors.append('blue')  # Default color if neither S1A nor S1B

    plt.figure(figsize=(14, 7))
    plt.plot(dates, percentages, linestyle='-', color='blue', alpha=0.7, label='Non-Forest %')

    # Plot points with custom colors
    for i, (date, percentage) in enumerate(zip(dates, percentages)):
        plt.scatter(date, percentage, color=colors[i], s=50)  # Adjust 's' for marker size

    # Add a vertical line to mark the deforestation detection date
    if deforestation_date:
        plt.axvline(deforestation_date, color='red', linestyle='--', label=f'Deforestation Detected on {deforestation_date}')

    # Format x-axis dates for better readability
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
    plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=3))
    plt.gcf().autofmt_xdate()

    plt.xlabel('Date')
    plt.ylabel('Non-Forest Percentage (%)')
    plt.title('Non-Forest Percentage Over Time')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

def visualize_predictions(initial_predictions, initial_file_date, final_predictions, final_file_date, transform):
    """Visualize the initial and final predictions side by side with a binary legend and projection values."""
    fig, axes = plt.subplots(1, 2, figsize=(20, 10))
    
    # Map predictions to colors (forest: green, non-forest: brown)
    cmap = mcolors.ListedColormap(['brown', 'green'])
    
    # Initial map
    im1 = axes[0].imshow(initial_predictions, cmap=cmap, extent=[transform[2], transform[2] + transform[0] * initial_predictions.shape[1],
                                                                 transform[5] + transform[4] * initial_predictions.shape[0], transform[5]])
    axes[0].set_title(f"Initial Predictions on {initial_file_date}")
    axes[0].set_xlabel("X Projection (m)")
    axes[0].set_ylabel("Y Projection (m)")
    axes[0].set_xticks([])  # Remove x-axis ticks for clarity

    # Final map
    im2 = axes[1].imshow(final_predictions, cmap=cmap, extent=[transform[2], transform[2] + transform[0] * final_predictions.shape[1],
                                                               transform[5] + transform[4] * final_predictions.shape[0], transform[5]])
    axes[1].set_title(f"Predictions on {final_file_date}")
    axes[1].set_xlabel("X Projection (m)")
    axes[1].set_ylabel("Y Projection (m)")

    # Create a custom legend
    legend_labels = {0: 'Non-Forest', 1: 'Forest'}
    patches = [plt.matplotlib.patches.Patch(color=cmap(i), label=legend_labels[i]) for i in legend_labels]
    fig.legend(handles=patches, bbox_to_anchor=(0.5, 0), loc='upper center', ncol=2)
    
    plt.tight_layout()
    plt.show()

def visualize_change_groups(initial_predictions, final_predictions, initial_file_date, final_file_date, transform):
    """Visualize the changes in land cover with four groups."""
    
    # Adjust the sizes to match by trimming the larger array
    min_h = min(initial_predictions.shape[0], final_predictions.shape[0])
    min_w = min(initial_predictions.shape[1], final_predictions.shape[1])
    
    initial_predictions = initial_predictions[:min_h, :min_w]
    final_predictions = final_predictions[:min_h, :min_w]
    
    fig, ax = plt.subplots(figsize=(10, 10))
    
    # Create a map for the four groups
    map_output = np.zeros_like(initial_predictions)

    # Define the four groups
    map_output[(initial_predictions == 1) & (final_predictions == 1)] = 1  # Forest that stayed forest (green)
    map_output[(initial_predictions == 1) & (final_predictions == 0)] = 2  # Forest that deforested (red)
    map_output[(initial_predictions == 0) & (final_predictions == 0)] = 3  # Non-forest that stayed non-forest (brown)
    map_output[(initial_predictions == 0) & (final_predictions == 1)] = 4  # Non-forest that became forest (light green)

    # Define the colormap
    cmap = mcolors.ListedColormap(['green', 'red', 'brown', 'lightgreen'])
    
    # Plot the map
    im = ax.imshow(map_output, cmap=cmap, extent=[transform[2], transform[2] + transform[0] * map_output.shape[1],
                                                  transform[5] + transform[4] * map_output.shape[0], transform[5]])

    ax.set_title(f"Land Cover Change: Initial ({initial_file_date}) to Final ({final_file_date})")
    ax.set_xlabel("X Projection (m)")
    ax.set_ylabel("Y Projection (m)")

    # Create a custom legend
    legend_labels = {
        1: 'Forest stayed Forest',
        2: 'Forest deforested',
        3: 'Non-Forest stayed Non-Forest',
        4: 'Non-Forest became Forest'
    }
    # Use the correct indices for the legend
    patches = [plt.matplotlib.patches.Patch(color=cmap(i-1), label=legend_labels[i]) for i in range(1, 5)]
    fig.legend(handles=patches, bbox_to_anchor=(1.05, 1), loc='upper left')
    
    plt.tight_layout() 
    plt.show()
# Out:
# Coordinate Reference System (CRS): EPSG:32720
# Coordinate Range (Bounding Box):
#   Min Longitude (West): 845580.0
#   Max Longitude (East): 847160.0
#   Min Latitude (South): 9329240.0
#   Max Latitude (North): 9331190.0

# %%
def classify_and_detect_deforestation(polygon_gdf, tif_files, method='combination'):
    # Sort the files by date before processing
    tif_files = sorted(tif_files, key=extract_date_from_filename)
    
    previous_classification = None
    total_files = len(tif_files)
    non_forest_summary = []
    initial_predictions = None  # To store the initial prediction map
    initial_file_date = None
    final_predictions = None  # To store the final prediction map
    final_file_date = None
    deforestation_detected = False  # Track if deforestation has been detected
    deforestation_date = None  # To store the date of deforestation detection

    baseline_period = [datetime(2015, 1, 1).date(), datetime(2016, 1, 1).date()]  # Define your stable period here

    for index, tif_file in enumerate(tif_files):
        sys.stdout.write(f"\rProcessing file {index + 1} out of {total_files}...")
        sys.stdout.flush()

        tif_path = os.path.join(time_series_dir, tif_file)
        with rasterio.open(tif_path) as src:
            out_image, out_transform = mask(src, polygon_gdf.geometry, crop=True)
            out_image = out_image.astype(np.float32)
            out_image = np.nan_to_num(out_image, nan=-9999)

            h, w = out_image.shape[1], out_image.shape[2]
            valid_features = []

            for i in range(h):
                for j in range(w):
                    tile_features = extract_features(out_image[:, i:i+1, j:j+1])
                    if tile_features is not None:
                        valid_features.append(tile_features)

            if not valid_features:
                continue

            # Convert list of features into a 2D numpy array
            valid_features = np.vstack(valid_features)

            # Normalize the features using the scaler
            valid_features_normalized = scaler.transform(valid_features)

            # Classify the pixels using the loaded model
            predictions = forest_classifier.predict(valid_features_normalized).reshape(h, w)

            # Store the initial prediction map and date
            if initial_predictions is None:
                initial_predictions = predictions
                initial_file_date = extract_date_from_filename(tif_file)

            # Always update the final predictions and date
            final_predictions = predictions
            final_file_date = extract_date_from_filename(tif_file)

            # Calculate the number of non-forest pixels and the percentage
            non_forest_pixels = np.sum(predictions == 0)
            total_pixels = predictions.size
            non_forest_percentage = (non_forest_pixels / total_pixels) * 100

            # Store the summary data
            non_forest_summary.append((final_file_date, non_forest_percentage))

            # Choose the deforestation detection method
            if method == 'rate_of_change':
                if index > 0 and is_deforested_rate_of_change(non_forest_summary[index-1][1], non_forest_percentage):
                    if not deforestation_detected:
                        deforestation_detected = True
                        deforestation_date = final_file_date
                        print(f"\nDeforestation detected on: {deforestation_date}")
                        visualize_predictions(initial_predictions, initial_file_date, final_predictions, final_file_date, out_transform)
                        visualize_change_groups(initial_predictions, final_predictions, initial_file_date, final_file_date, out_transform)
            elif method == 'moving_average':
                if len(non_forest_summary) >= 5:  # Ensure there are enough data points for smoothing
                    smoothed_percentages = smooth_data([percent for _, percent in non_forest_summary])
                    smoothed_percentage = smoothed_percentages.iloc[-1] if len(smoothed_percentages) > 0 else None
                    if smoothed_percentage is not None and is_deforested_moving_average(smoothed_percentage):
                        if not deforestation_detected:
                            deforestation_detected = True
                            deforestation_date = final_file_date
                            print(f"\nDeforestation detected on: {deforestation_date}")
                            visualize_predictions(initial_predictions, initial_file_date, final_predictions, final_file_date, out_transform)
                            visualize_change_groups(initial_predictions, final_predictions, initial_file_date, final_file_date, out_transform)
            elif method == 'baseline':
                baseline = calculate_baseline(non_forest_summary, baseline_period)
                if is_deforested_baseline(non_forest_percentage, baseline):
                    if not deforestation_detected:
                        deforestation_detected = True
                        deforestation_date = final_file_date
                        print(f"\nDeforestation detected on: {deforestation_date}")
                        visualize_predictions(initial_predictions, initial_file_date, final_predictions, final_file_date, out_transform)
                        visualize_change_groups(initial_predictions, final_predictions, initial_file_date, final_file_date, out_transform)
            elif method == 'combination':
                if index > 0:
                    baseline = calculate_baseline(non_forest_summary, baseline_period)
                    if is_deforested_combination(non_forest_summary[index-1][1], non_forest_percentage, baseline):
                        if not deforestation_detected:
                            deforestation_detected = True
                            deforestation_date = final_file_date
                            print(f"\nDeforestation detected on: {deforestation_date}")
                            visualize_predictions(initial_predictions, initial_file_date, final_predictions, final_file_date, out_transform)
                            visualize_change_groups(initial_predictions, final_predictions, initial_file_date, final_file_date, out_transform)
            elif method == 'temporal_consistency':
                if check_temporal_consistency(non_forest_summary):
                    if not deforestation_detected:
                        deforestation_detected = True
                        deforestation_date = final_file_date
                        print(f"\nDeforestation detected on: {deforestation_date}")
                        visualize_predictions(initial_predictions, initial_file_date, final_predictions, final_file_date, out_transform)
                        visualize_change_groups(initial_predictions, final_predictions, initial_file_date, final_file_date, out_transform)

            previous_classification = predictions

    # Plot the initial and final predictions only once
    if initial_predictions is not None and final_predictions is not None and deforestation_detected:
        visualize_predictions(initial_predictions, initial_file_date, final_predictions, final_file_date, out_transform)
        visualize_change_groups(initial_predictions, final_predictions, initial_file_date, final_file_date, out_transform)

    # Plot the summary and include the deforestation detection date
    plot_non_forest_percentage(non_forest_summary, tif_files, deforestation_date)

    if deforestation_detected:
        print(f"\nDeforestation detected on: {deforestation_date}")
    else:
        print("\nNo significant deforestation detected in the given time series.")

# %%
# Run the detection function with the combination method
classify_and_detect_deforestation(gdf, tif_files, method='combination')
# Out:
# Processing file 2 out of 241...Rate of Change: 25.159943977591038, Exceeds Threshold: False
# Processing file 3 out of 241...Rate of Change: 6.069094304388422, Exceeds Threshold: False
# Processing file 4 out of 241...Rate of Change: -6.162464985994397, Exceeds Threshold: False
# Processing file 5 out of 241...Rate of Change: 13.912231559290376, Exceeds Threshold: False
# Processing file 6 out of 241...Rate of Change: -12.044817927170854, Exceeds Threshold: False
# Processing file 7 out of 241...Rate of Change: 9.243697478991585, Exceeds Threshold: False
# Processing file 8 out of 241...Rate of Change: 2.5210084033613427, Exceeds Threshold: False
# Processing file 9 out of 241...Rate of Change: -15.59290382819794, Exceeds Threshold: False
# Processing file 10 out of 241...Rate of Change: -2.2408963585434165, Exceeds Threshold: False
# Processing file 11 out of 241...Rate of Change: 11.577964519140984, Exceeds Threshold: False
# Processing file 12 out of 241...Rate of Change: -10.177404295051353, Exceeds Threshold: False
# Processing file 13 out of 241...Rate of Change: -0.6535947712418277, Exceeds Threshold: False
# Processing file 14 out of 241...Rate of Change: 6.629318394024281, Exceeds Threshold: False
# Processing file 15 out of 241...Rate of Change: 1.7740429505135396, Exceeds Threshold: False
# Processing file 16 out of 241...Rate of Change: -8.40336134453782, Exceeds Threshold: False
# Processing file 17 out of 241...Rate of Change: 2.801120448179269, Exceeds Threshold: False
# Processing file 18 out of 241...Rate of Change: 1.4939309056956134, Exceeds Threshold: False
# Processing file 19 out of 241...Rate of Change: -8.963585434173666, Exceeds Threshold: False
# Processing file 20 out of 241...Rate of Change: 12.885154061624647, Exceeds Threshold: False
# Processing file 21 out of 241...Rate of Change: -7.096171802054158, Exceeds Threshold: False
# Processing file 22 out of 241...Rate of Change: 3.6414565826330545, Exceeds Threshold: False
# Processing file 23 out of 241...Rate of Change: -6.9094304388422, Exceeds Threshold: False
# Processing file 24 out of 241...Rate of Change: -5.602240896358538, Exceeds Threshold: False
# Processing file 25 out of 241...Rate of Change: 20.07469654528478, Exceeds Threshold: False
# Processing file 26 out of 241...Rate of Change: 5.7889822595704885, Exceeds Threshold: False
# Processing file 27 out of 241...Rate of Change: -2.801120448179269, Exceeds Threshold: False
# Processing file 28 out of 241...Rate of Change: -4.201680672268914, Exceeds Threshold: False
# Processing file 29 out of 241...Rate of Change: -0.5602240896358524, Exceeds Threshold: False
# Processing file 30 out of 241...Rate of Change: -0.46685340802987696, Exceeds Threshold: False
# Processing file 31 out of 241...Rate of Change: -0.37348272642390157, Exceeds Threshold: False
# Processing file 32 out of 241...Rate of Change: 7.93650793650793, Exceeds Threshold: False
# Processing file 33 out of 241...Rate of Change: -1.5873015873015817, Exceeds Threshold: False
# Processing file 34 out of 241...Rate of Change: -12.41830065359477, Exceeds Threshold: False
# Processing file 35 out of 241...Rate of Change: 2.614379084967325, Exceeds Threshold: False
# Processing file 36 out of 241...Rate of Change: -11.204481792717097, Exceeds Threshold: False
# Processing file 37 out of 241...Rate of Change: 8.776844070961722, Exceeds Threshold: False
# Processing file 38 out of 241...Rate of Change: 1.7740429505135467, Exceeds Threshold: False
# Processing file 39 out of 241...Rate of Change: -0.7469654528478173, Exceeds Threshold: False
# Processing file 40 out of 241...Rate of Change: -2.147525676937441, Exceeds Threshold: False
# Processing file 41 out of 241...Rate of Change: -3.361344537815121, Exceeds Threshold: False
# Processing file 42 out of 241...Rate of Change: -1.6806722689075642, Exceeds Threshold: False
# Processing file 43 out of 241...Rate of Change: -4.94864612511671, Exceeds Threshold: False
# Processing file 44 out of 241...Rate of Change: 12.418300653594763, Exceeds Threshold: False
# Processing file 45 out of 241...Rate of Change: -2.4276377217553673, Exceeds Threshold: False
# Processing file 46 out of 241...Rate of Change: -0.6535947712418277, Exceeds Threshold: False
# Processing file 47 out of 241...Rate of Change: 5.882352941176471, Exceeds Threshold: False
# Processing file 48 out of 241...Rate of Change: -11.577964519140991, Exceeds Threshold: False
# Processing file 49 out of 241...Rate of Change: 0.18674136321195078, Exceeds Threshold: False
# Processing file 50 out of 241...Rate of Change: 5.228758169934643, Exceeds Threshold: False
# Processing file 51 out of 241...Rate of Change: 6.909430438842207, Exceeds Threshold: False
# Processing file 52 out of 241...Rate of Change: -8.683473389355747, Exceeds Threshold: False
# Processing file 53 out of 241...Rate of Change: 3.4547152194211037, Exceeds Threshold: False
# Processing file 54 out of 241...Rate of Change: 6.349206349206348, Exceeds Threshold: False
# Processing file 55 out of 241...Rate of Change: 12.044817927170868, Exceeds Threshold: False
# Processing file 56 out of 241...Rate of Change: -8.309990662931838, Exceeds Threshold: False
# Processing file 57 out of 241...Rate of Change: -4.014939309056956, Exceeds Threshold: False
# Processing file 58 out of 241...Rate of Change: -5.415499533146594, Exceeds Threshold: False
# Processing file 59 out of 241...Rate of Change: 2.614379084967325, Exceeds Threshold: False
# Processing file 60 out of 241...Rate of Change: 8.68347338935574, Exceeds Threshold: False
# Processing file 61 out of 241...Rate of Change: -13.258636788048555, Exceeds Threshold: False
# Processing file 62 out of 241...Rate of Change: 11.297852474323065, Exceeds Threshold: False
# Processing file 63 out of 241...Rate of Change: 0.18674136321195078, Exceeds Threshold: False
# Processing file 64 out of 241...Rate of Change: 0.09337068160597539, Exceeds Threshold: False
# Processing file 65 out of 241...Rate of Change: 5.602240896358538, Exceeds Threshold: False
# Processing file 66 out of 241...Rate of Change: -12.324929971988787, Exceeds Threshold: False
# Processing file 67 out of 241...Rate of Change: 10.364145658263297, Exceeds Threshold: False
# Processing file 68 out of 241...Rate of Change: -13.725490196078425, Exceeds Threshold: False
# Processing file 69 out of 241...Rate of Change: -0.09337068160597539, Exceeds Threshold: False
# Processing file 70 out of 241...Rate of Change: 13.165266106442573, Exceeds Threshold: False
# Processing file 71 out of 241...Rate of Change: -7.096171802054151, Exceeds Threshold: False
# Processing file 72 out of 241...Rate of Change: 7.096171802054151, Exceeds Threshold: False
# Processing file 73 out of 241...Rate of Change: -7.843137254901954, Exceeds Threshold: False
# Processing file 74 out of 241...Rate of Change: 0.18674136321195078, Exceeds Threshold: False
# Processing file 75 out of 241...Rate of Change: 10.457516339869272, Exceeds Threshold: False
# Processing file 76 out of 241...Rate of Change: -14.472455648926235, Exceeds Threshold: False
# Processing file 77 out of 241...Rate of Change: 9.617180205415508, Exceeds Threshold: False
# Processing file 78 out of 241...Rate of Change: -4.761904761904766, Exceeds Threshold: False
# Processing file 79 out of 241...Rate of Change: 2.9878618113912268, Exceeds Threshold: False
# Processing file 80 out of 241...Rate of Change: -4.855275443510742, Exceeds Threshold: False
# Processing file 81 out of 241...Rate of Change: 2.7077497665732935, Exceeds Threshold: False
# Processing file 82 out of 241...Rate of Change: -4.481792717086826, Exceeds Threshold: False
# Processing file 83 out of 241...Rate of Change: 7.376283846872077, Exceeds Threshold: False
# Processing file 84 out of 241...Rate of Change: 5.3221288515406115, Exceeds Threshold: False
# Processing file 85 out of 241...Rate of Change: -15.40616246498599, Exceeds Threshold: False
# Processing file 86 out of 241...Rate of Change: 10.830999066293181, Exceeds Threshold: False
# Processing file 87 out of 241...Rate of Change: 13.258636788048562, Exceeds Threshold: False
# Processing file 88 out of 241...Rate of Change: -20.915032679738566, Exceeds Threshold: False
# Processing file 89 out of 241...Rate of Change: 7.563025210084028, Exceeds Threshold: False
# Processing file 90 out of 241...Rate of Change: 2.614379084967318, Exceeds Threshold: False
# Processing file 91 out of 241...Rate of Change: 4.948646125116717, Exceeds Threshold: False
# Processing file 92 out of 241...Rate of Change: -0.18674136321195078, Exceeds Threshold: False
# Processing file 93 out of 241...Rate of Change: -3.1746031746031775, Exceeds Threshold: False
# Processing file 94 out of 241...Rate of Change: 0.09337068160597539, Exceeds Threshold: False
# Processing file 95 out of 241...Rate of Change: -9.430438842203543, Exceeds Threshold: False
# Processing file 96 out of 241...Rate of Change: 15.779645191409898, Exceeds Threshold: False
# Processing file 97 out of 241...Rate of Change: -8.02987861811392, Exceeds Threshold: False
# Processing file 98 out of 241...Rate of Change: -1.21381886087768, Exceeds Threshold: False
# Processing file 99 out of 241...Rate of Change: -11.577964519140991, Exceeds Threshold: False
# Processing file 100 out of 241...Rate of Change: 5.415499533146594, Exceeds Threshold: False
# Processing file 101 out of 241...Rate of Change: 4.014939309056956, Exceeds Threshold: False
# Processing file 102 out of 241...Rate of Change: -2.054154995331473, Exceeds Threshold: False
# Processing file 103 out of 241...Rate of Change: -3.081232492997188, Exceeds Threshold: False
# Processing file 104 out of 241...Rate of Change: -3.6414565826330616, Exceeds Threshold: False
# Processing file 105 out of 241...Rate of Change: -3.1746031746031704, Exceeds Threshold: False
# Processing file 106 out of 241...Rate of Change: 5.0420168067226925, Exceeds Threshold: False
# Processing file 107 out of 241...Rate of Change: -3.6414565826330545, Exceeds Threshold: False
# Processing file 108 out of 241...Rate of Change: 0.9337068160597539, Exceeds Threshold: False
# Processing file 109 out of 241...Rate of Change: 1.6806722689075713, Exceeds Threshold: False
# Processing file 110 out of 241...Rate of Change: 6.7226890756302495, Exceeds Threshold: False
# Processing file 111 out of 241...Rate of Change: -4.201680672268914, Exceeds Threshold: False
# Processing file 112 out of 241...Rate of Change: 12.97852474323063, Exceeds Threshold: False
# Processing file 113 out of 241...Rate of Change: -10.084033613445385, Exceeds Threshold: False
# Processing file 114 out of 241...Rate of Change: -11.484593837535009, Exceeds Threshold: False
# Processing file 115 out of 241...Rate of Change: 8.68347338935574, Exceeds Threshold: False
# Processing file 116 out of 241...Rate of Change: -1.5873015873015817, Exceeds Threshold: False
# Processing file 117 out of 241...Rate of Change: -1.400560224089645, Exceeds Threshold: False
# Processing file 118 out of 241...Rate of Change: -1.1204481792717047, Exceeds Threshold: False
# Processing file 119 out of 241...Rate of Change: 8.02987861811392, Exceeds Threshold: False
# Processing file 120 out of 241...Rate of Change: -0.8403361344537927, Exceeds Threshold: False
# Processing file 121 out of 241...Rate of Change: -5.695611577964506, Exceeds Threshold: False
# Processing file 122 out of 241...Rate of Change: -2.1475256769374482, Exceeds Threshold: False
# Processing file 123 out of 241...Rate of Change: 4.201680672268907, Exceeds Threshold: False
# Processing file 124 out of 241...Rate of Change: -4.761904761904766, Exceeds Threshold: False
# Processing file 125 out of 241...Rate of Change: 9.99066293183941, Exceeds Threshold: False
# Processing file 126 out of 241...Rate of Change: -10.644257703081237, Exceeds Threshold: False
# Processing file 127 out of 241...Rate of Change: 11.951447245564893, Exceeds Threshold: False
# Processing file 128 out of 241...Rate of Change: -2.0541549953314586, Exceeds Threshold: False
# Processing file 129 out of 241...Rate of Change: -1.867413632119522, Exceeds Threshold: False
# Processing file 130 out of 241...Rate of Change: -5.135387488328668, Exceeds Threshold: False
# Processing file 131 out of 241...Rate of Change: 19.60784313725491, Exceeds Threshold: False
# Processing file 132 out of 241...Rate of Change: -6.069094304388429, Exceeds Threshold: False
# Processing file 133 out of 241...Rate of Change: 5.695611577964527, Exceeds Threshold: False
# Processing file 134 out of 241...Rate of Change: -9.150326797385624, Exceeds Threshold: False
# Processing file 135 out of 241...Rate of Change: 11.577964519140984, Exceeds Threshold: False
# Processing file 136 out of 241...Rate of Change: -18.39402427637721, Exceeds Threshold: False
# Processing file 137 out of 241...Rate of Change: 8.683473389355733, Exceeds Threshold: False
# Processing file 138 out of 241...Rate of Change: 2.0541549953314657, Exceeds Threshold: False
# Processing file 139 out of 241...Rate of Change: -4.761904761904759, Exceeds Threshold: False
# Processing file 140 out of 241...Rate of Change: 1.7740429505135396, Exceeds Threshold: False
# Processing file 141 out of 241...Rate of Change: 0.0, Exceeds Threshold: False
# Processing file 142 out of 241...Rate of Change: -2.0541549953314657, Exceeds Threshold: False
# Processing file 143 out of 241...Rate of Change: 3.4547152194210966, Exceeds Threshold: False
# Processing file 144 out of 241...Rate of Change: -7.1895424836601265, Exceeds Threshold: False
# Processing file 145 out of 241...Rate of Change: -0.37348272642390157, Exceeds Threshold: False
# Processing file 146 out of 241...Rate of Change: -3.6414565826330474, Exceeds Threshold: False
# Processing file 147 out of 241...Rate of Change: 12.418300653594763, Exceeds Threshold: False
# Processing file 148 out of 241...Rate of Change: -3.9215686274509736, Exceeds Threshold: False
# Processing file 149 out of 241...Rate of Change: 1.8674136321195078, Exceeds Threshold: False
# Processing file 150 out of 241...Rate of Change: 2.5210084033613427, Exceeds Threshold: False
# Processing file 151 out of 241...Rate of Change: -3.6414565826330474, Exceeds Threshold: False
# Processing file 152 out of 241...Rate of Change: -9.617180205415494, Exceeds Threshold: False
# Processing file 153 out of 241...Rate of Change: 10.550887021475248, Exceeds Threshold: False
# Processing file 154 out of 241...Rate of Change: -10.830999066293174, Exceeds Threshold: False
# Processing file 155 out of 241...Rate of Change: -0.653594771241842, Exceeds Threshold: False
# Processing file 156 out of 241...Rate of Change: -1.3071895424836555, Exceeds Threshold: False
# Processing file 157 out of 241...Rate of Change: 3.4547152194211037, Exceeds Threshold: False
# Processing file 158 out of 241...Rate of Change: 4.48179271708684, Exceeds Threshold: False
# Processing file 159 out of 241...Rate of Change: 4.3884220354808505, Exceeds Threshold: False
# Processing file 160 out of 241...Rate of Change: -11.20448179271709, Exceeds Threshold: False
# Processing file 161 out of 241...Rate of Change: 10.644257703081237, Exceeds Threshold: False
# Processing file 162 out of 241...Rate of Change: -10.644257703081237, Exceeds Threshold: False
# Processing file 163 out of 241...Rate of Change: 2.9878618113912268, Exceeds Threshold: False
# Processing file 164 out of 241...Rate of Change: -5.228758169934643, Exceeds Threshold: False
# Processing file 165 out of 241...Rate of Change: 4.5751633986928155, Exceeds Threshold: False
# Processing file 166 out of 241...Rate of Change: -6.349206349206355, Exceeds Threshold: False
# Processing file 167 out of 241...Rate of Change: 12.418300653594777, Exceeds Threshold: False
# Processing file 168 out of 241...Rate of Change: -12.605042016806728, Exceeds Threshold: False
# Processing file 169 out of 241...Rate of Change: 17.08683473389356, Exceeds Threshold: False
# Processing file 170 out of 241...Rate of Change: -15.312791783380021, Exceeds Threshold: False
# Processing file 171 out of 241...Rate of Change: 3.734827264239037, Exceeds Threshold: False
# Processing file 172 out of 241...Rate of Change: -2.52100840336135, Exceeds Threshold: False
# Processing file 173 out of 241...Rate of Change: -0.37348272642390157, Exceeds Threshold: False
# Processing file 174 out of 241...Rate of Change: -13.35200746965453, Exceeds Threshold: False
# Processing file 175 out of 241...Rate of Change: 9.803921568627452, Exceeds Threshold: False
# Processing file 176 out of 241...Rate of Change: 5.695611577964527, Exceeds Threshold: False
# Processing file 177 out of 241...Rate of Change: 0.2801120448179262, Exceeds Threshold: False
# Processing file 178 out of 241...Rate of Change: 7.749766573295979, Exceeds Threshold: False
# Processing file 179 out of 241...Rate of Change: -14.472455648926235, Exceeds Threshold: False
# Processing file 180 out of 241...Rate of Change: 12.885154061624654, Exceeds Threshold: False
# Processing file 181 out of 241...Rate of Change: -5.322128851540619, Exceeds Threshold: False
# Processing file 182 out of 241...Rate of Change: -0.5602240896358524, Exceeds Threshold: False
# Processing file 183 out of 241...Rate of Change: 20.54154995331465, Exceeds Threshold: False
# Processing file 184 out of 241...Rate of Change: -7.46965452847806, Exceeds Threshold: False
# Processing file 185 out of 241...Rate of Change: 14.845938375350144, Exceeds Threshold: True
#
# Deforestation detected on: 2021-07-13
# Processing file 186 out of 241...Rate of Change: -12.044817927170868, Exceeds Threshold: False
# Processing file 187 out of 241...Rate of Change: 5.228758169934636, Exceeds Threshold: False
# Processing file 188 out of 241...Rate of Change: 2.614379084967325, Exceeds Threshold: True
# Processing file 189 out of 241...Rate of Change: 0.5602240896358666, Exceeds Threshold: True
# Processing file 190 out of 241...Rate of Change: -3.734827264239044, Exceeds Threshold: False
# Processing file 191 out of 241...Rate of Change: 17.83380018674137, Exceeds Threshold: True
# Processing file 192 out of 241...Rate of Change: 3.828197945844991, Exceeds Threshold: True
# Processing file 193 out of 241...Rate of Change: -29.038281979458446, Exceeds Threshold: False
# Processing file 194 out of 241...Rate of Change: 27.450980392156865, Exceeds Threshold: True
# Processing file 195 out of 241...Rate of Change: 6.4425770308123305, Exceeds Threshold: True
# Processing file 196 out of 241...Rate of Change: 0.09337068160597539, Exceeds Threshold: True
# Processing file 197 out of 241...Rate of Change: -3.6414565826330545, Exceeds Threshold: True
# Processing file 198 out of 241...Rate of Change: -3.3613445378151283, Exceeds Threshold: True
# Processing file 199 out of 241...Rate of Change: 4.94864612511671, Exceeds Threshold: True
# Processing file 200 out of 241...Rate of Change: 0.5602240896358524, Exceeds Threshold: True
# Processing file 201 out of 241...Rate of Change: 0.8403361344537927, Exceeds Threshold: True
# Processing file 202 out of 241...Rate of Change: -27.824463118580766, Exceeds Threshold: False
# Processing file 203 out of 241...Rate of Change: 28.664799253034545, Exceeds Threshold: True
# Processing file 204 out of 241...Rate of Change: -2.1475256769374482, Exceeds Threshold: True
# Processing file 205 out of 241...Rate of Change: -47.992530345471515, Exceeds Threshold: False
# Processing file 206 out of 241...Rate of Change: 46.965452847805786, Exceeds Threshold: True
# Processing file 207 out of 241...Rate of Change: -44.91129785247433, Exceeds Threshold: False
# Processing file 208 out of 241...Rate of Change: 0.653594771241842, Exceeds Threshold: False
# Processing file 209 out of 241...Rate of Change: -6.629318394024281, Exceeds Threshold: False
# Processing file 210 out of 241...Rate of Change: 32.02614379084968, Exceeds Threshold: True
# Processing file 211 out of 241...Rate of Change: 14.65919701213818, Exceeds Threshold: True
# Processing file 212 out of 241...Rate of Change: -4.575163398692808, Exceeds Threshold: True
# Processing file 213 out of 241...Rate of Change: -34.45378151260504, Exceeds Threshold: False
# Processing file 214 out of 241...Rate of Change: 38.93557422969187, Exceeds Threshold: True
# Processing file 215 out of 241...Rate of Change: -6.349206349206355, Exceeds Threshold: True
# Processing file 216 out of 241...Rate of Change: -31.279178338001863, Exceeds Threshold: False
# Processing file 217 out of 241...Rate of Change: -4.014939309056956, Exceeds Threshold: False
# Processing file 218 out of 241...Rate of Change: 40.89635854341737, Exceeds Threshold: True
# Processing file 219 out of 241...Rate of Change: -8.77684407096173, Exceeds Threshold: True
# Processing file 220 out of 241...Rate of Change: -22.12885154061624, Exceeds Threshold: False
# Processing file 221 out of 241...Rate of Change: -3.267973856209153, Exceeds Threshold: False
# Processing file 222 out of 241...Rate of Change: 12.044817927170868, Exceeds Threshold: False
# Processing file 223 out of 241...Rate of Change: -16.900093370681596, Exceeds Threshold: False
# Processing file 224 out of 241...Rate of Change: 24.55648926237162, Exceeds Threshold: True
# Processing file 225 out of 241...Rate of Change: -24.74323062558357, Exceeds Threshold: False
# Processing file 226 out of 241...Rate of Change: 12.324929971988787, Exceeds Threshold: False
# Processing file 227 out of 241...Rate of Change: 18.020541549953307, Exceeds Threshold: True
# Processing file 228 out of 241...Rate of Change: -0.7469654528478031, Exceeds Threshold: True
# Processing file 229 out of 241...Rate of Change: 1.4939309056956205, Exceeds Threshold: True
# Processing file 230 out of 241...Rate of Change: -2.9878618113912268, Exceeds Threshold: True
# Processing file 231 out of 241...Rate of Change: 10.457516339869287, Exceeds Threshold: True
# Processing file 232 out of 241...Rate of Change: -6.629318394024281, Exceeds Threshold: True
# Processing file 233 out of 241...Rate of Change: -40.056022408963585, Exceeds Threshold: False
# Processing file 234 out of 241...Rate of Change: 34.36041083099907, Exceeds Threshold: True
# Processing file 235 out of 241...Rate of Change: 1.5873015873015817, Exceeds Threshold: True
# Processing file 236 out of 241...Rate of Change: -11.671335200746967, Exceeds Threshold: False
# Processing file 237 out of 241...Rate of Change: 4.1083099906629315, Exceeds Threshold: False
# Processing file 238 out of 241...Rate of Change: 6.535947712418306, Exceeds Threshold: True
# Processing file 239 out of 241...Rate of Change: -7.563025210084035, Exceeds Threshold: False
# Processing file 240 out of 241...Rate of Change: 13.445378151260499, Exceeds Threshold: True
# Processing file 241 out of 241...Rate of Change: -8.963585434173666, Exceeds Threshold: True
# Deforestation detected on: 2021-07-13
